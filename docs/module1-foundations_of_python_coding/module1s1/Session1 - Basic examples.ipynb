# %% [markdown]
# # RECODE Session 1
# Basic test & Examples

# %%
print("Hello noteboook!")
# Out:
# Hello noteboook!

# %% [markdown]
# ## Overview
# Some calculations:

# %%
x = 5
y = 3
z = x + y
z
# Out:
# 8
